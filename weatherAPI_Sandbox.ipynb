# %%
from dotenv import load_dotenv
load_dotenv(override=True)

from weatherTool_V2 import get_city_forecast

city_name = "Monterrey, Mexico"
response = get_city_forecast(city_name)

print(f"Response: {response}")
